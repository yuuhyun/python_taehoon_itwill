# %% [markdown]
# <a href="https://colab.research.google.com/github/yuuhyun/python_taehoon_itwill/blob/main/20250509_python23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DataFrame Merge(Join)

# %%
emp = pd.DataFrame(data={
    'empno': [100, 101, 200, 201],
    'ename': ['홍길동', '오쌤', 'Scott', 'King'],
    'deptno': [10, 20, 20, 40]
})
emp
# Out:
#    empno  ename  deptno
# 0    100    홍길동      10
# 1    101     오쌤      20
# 2    200  Scott      20
# 3    201   King      40

# %%
dept = pd.DataFrame(data={
    'deptno': [10, 20, 30],
    'dname': ['IT', 'HR', 'Sales']
})

dept
# Out:
#    deptno  dname
# 0      10     IT
# 1      20     HR
# 2      30  Sales

# %% [markdown]
# * `pd.merge(df1, df2, how, on, ...)` 함수(function)
# * `pd.DataFrame.merge(df, how, on, ..)` 메서드(method)
# * `how` 파라미터: merge(join) 방식 설정.
#     * inner, left, right, outer
#     * merge의 기본값은 inner. how='inner' 생략 가능.
# * `on` 파라미터 : merge(join)의 기준이 되는 컬럼(컬럼들의 리스트)을 설정.
#     * merge(join)를 하려는 두 개의 데이터프레임에서 컬럼 이름이 같은 경우에는 on 파라미터 설정을 생략 가능.

# %% [markdown]
# ## inner join

# %%
pd.merge(emp, dept)
# how='inner', on='deptno' 생략
# Out:
#    empno  ename  deptno dname
# 0    100    홍길동      10    IT
# 1    101     오쌤      20    HR
# 2    200  Scott      20    HR

# %%
emp.merge(dept)
# Out:
#    empno  ename  deptno dname
# 0    100    홍길동      10    IT
# 1    101     오쌤      20    HR
# 2    200  Scott      20    HR

# %%
dept.merge(emp)
# Out:
#    deptno dname  empno  ename
# 0      10    IT    100    홍길동
# 1      20    HR    101     오쌤
# 2      20    HR    200  Scott

# %% [markdown]
# ## left outer join

# %%
pd.merge(emp, dept, how='left')
# Out:
#    empno  ename  deptno dname
# 0    100    홍길동      10    IT
# 1    101     오쌤      20    HR
# 2    200  Scott      20    HR
# 3    201   King      40   NaN

# %% [markdown]
# ## right(outer) join

# %%
pd.merge(emp, dept, how='right')
# Out:
#    empno  ename  deptno  dname
# 0  100.0    홍길동      10     IT
# 1  101.0     오쌤      20     HR
# 2  200.0  Scott      20     HR
# 3    NaN    NaN      30  Sales

# %% [markdown]
# ## full(outer) join

# %%
pd.merge(emp, dept, how='outer')
# Out:
#    empno  ename  deptno  dname
# 0  100.0    홍길동      10     IT
# 1  101.0     오쌤      20     HR
# 2  200.0  Scott      20     HR
# 3    NaN    NaN      30  Sales
# 4  201.0   King      40    NaN

# %% [markdown]
# ## merge(join) 기준이 되는 컬럼 이름이 다른 경우

# %%
emp
# Out:
#    empno  ename  deptno
# 0    100    홍길동      10
# 1    101     오쌤      20
# 2    200  Scott      20
# 3    201   King      40

# %%
dept = pd.DataFrame(data={
    'empno': [100, 101, 200, 201],
    'ename': ['홍길동', '오쌤', 'Scott', 'King'],
    'deptno': [10, 20, 20, 40]
})
dept
# Out:
#    empno  ename  deptno
# 0    100    홍길동      10
# 1    101     오쌤      20
# 2    200  Scott      20
# 3    201   King      40

# %%
dept = pd.DataFrame(data={
    'dno': [10, 20, 30],
    'dname': ['IT', 'HR', 'Sales']
})

dept
# Out:
#    dno  dname
# 0   10     IT
# 1   20     HR
# 2   30  Sales

# %%
pd.merge(emp, dept, left_on = 'deptno', right_on='dno')
# Out:
#    empno  ename  deptno  dno dname
# 0    100    홍길동      10   10    IT
# 1    101     오쌤      20   20    HR
# 2    200  Scott      20   20    HR

# %% [markdown]
# # merge 연습문제

# %%
# 사번, 이름, 업무, 매니저 사번, 입사날짜, 급여, 수당, 부서번호
emp_col_names = ['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno']
emp_file = "https://raw.githubusercontent.com/JakeOh/202504_itwill_oracle88/refs/heads/main/emp.csv"

# %%
# 부서번호, 부서이름, 부서위치
dept_col_names = ['deptno', 'dname', 'loc']
dept_file ="https://raw.githubusercontent.com/JakeOh/202504_itwill_oracle88/refs/heads/main/dept.csv"

# %%
# emp_file을 읽어서 데이터프레임을 생성.
# dept_file을 읽어서 데이터프레임을 생성.
emp = pd.read_csv(emp_file, names=emp_col_names)
dept = pd.read_csv(dept_file, names=dept_col_names)

# %% [markdown]
# * emp, dept 데이터프레임을 inner, left, right, outer join의 결과를 확인하세요.

# %%
pd.merge(emp, dept)
# Out:
#     empno   ename        job     mgr             hiredate     sal    comm  \
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 7    7788   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0     NaN
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 10   7876   ADAMS      CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
#
#     deptno       dname       loc
# 0       20    RESEARCH    DALLAS
# 1       30       SALES   CHICAGO
# 2       30       SALES   CHICAGO
# 3       20    RESEARCH    DALLAS
# 4       30       SALES   CHICAGO
# 5       30       SALES   CHICAGO
# 6       10  ACCOUNTING  NEW YORK
# 7       20    RESEARCH    DALLAS
# 8       10  ACCOUNTING  NEW YORK
# 9       30       SALES   CHICAGO
# 10      20    RESEARCH    DALLAS
# 11      30       SALES   CHICAGO
# 12      20    RESEARCH    DALLAS
# 13      10  ACCOUNTING  NEW YORK

# %%
pd.merge(emp, dept, how='left')
# Out:
#     empno   ename        job     mgr             hiredate     sal    comm  \
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 7    7788   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0     NaN
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 10   7876   ADAMS      CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
#
#     deptno       dname       loc
# 0       20    RESEARCH    DALLAS
# 1       30       SALES   CHICAGO
# 2       30       SALES   CHICAGO
# 3       20    RESEARCH    DALLAS
# 4       30       SALES   CHICAGO
# 5       30       SALES   CHICAGO
# 6       10  ACCOUNTING  NEW YORK
# 7       20    RESEARCH    DALLAS
# 8       10  ACCOUNTING  NEW YORK
# 9       30       SALES   CHICAGO
# 10      20    RESEARCH    DALLAS
# 11      30       SALES   CHICAGO
# 12      20    RESEARCH    DALLAS
# 13      10  ACCOUNTING  NEW YORK

# %%
pd.merge(emp, dept, how='right')
# Out:
#      empno   ename        job     mgr             hiredate     sal    comm  \
# 0   7782.0   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 1   7839.0    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0     NaN
# 2   7934.0  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
# 3   7369.0   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 4   7566.0   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 5   7788.0   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 6   7876.0   ADAMS      CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 7   7902.0    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 8   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 9   7521.0    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 10  7654.0  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 11  7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 12  7844.0  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 13  7900.0   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 14     NaN     NaN        NaN     NaN                  NaN     NaN     NaN
#
#     deptno       dname       loc
# 0       10  ACCOUNTING  NEW YORK
# 1       10  ACCOUNTING  NEW YORK
# 2       10  ACCOUNTING  NEW YORK
# 3       20    RESEARCH    DALLAS
# 4       20    RESEARCH    DALLAS
# 5       20    RESEARCH    DALLAS
# 6       20    RESEARCH    DALLAS
# 7       20    RESEARCH    DALLAS
# 8       30       SALES   CHICAGO
# 9       30       SALES   CHICAGO
# 10      30       SALES   CHICAGO
# 11      30       SALES   CHICAGO
# 12      30       SALES   CHICAGO
# 13      30       SALES   CHICAGO
# 14      40  OPERATIONS    BOSTON

# %%
pd.merge(emp, dept, how='outer')
# Out:
#      empno   ename        job     mgr             hiredate     sal    comm  \
# 0   7782.0   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 1   7839.0    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0     NaN
# 2   7934.0  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
# 3   7369.0   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 4   7566.0   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 5   7788.0   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 6   7876.0   ADAMS      CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 7   7902.0    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 8   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 9   7521.0    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 10  7654.0  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 11  7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 12  7844.0  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 13  7900.0   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 14     NaN     NaN        NaN     NaN                  NaN     NaN     NaN
#
#     deptno       dname       loc
# 0       10  ACCOUNTING  NEW YORK
# 1       10  ACCOUNTING  NEW YORK
# 2       10  ACCOUNTING  NEW YORK
# 3       20    RESEARCH    DALLAS
# 4       20    RESEARCH    DALLAS
# 5       20    RESEARCH    DALLAS
# 6       20    RESEARCH    DALLAS
# 7       20    RESEARCH    DALLAS
# 8       30       SALES   CHICAGO
# 9       30       SALES   CHICAGO
# 10      30       SALES   CHICAGO
# 11      30       SALES   CHICAGO
# 12      30       SALES   CHICAGO
# 13      30       SALES   CHICAGO
# 14      40  OPERATIONS    BOSTON

# %% [markdown]
# 부서별 급여 평균

# %%
emp.groupby(by=['deptno']).sal.mean()
# Out:
# deptno
# 10    2916.666667
# 20    2175.000000
# 30    1566.666667
# Name: sal, dtype: float64

# %%
emp_dept = pd.merge(emp,dept) # inner join
emp_dept.groupby(by='dname').sal.mean()
# Out:
# dname
# ACCOUNTING    2916.666667
# RESEARCH      2175.000000
# SALES         1566.666667
# Name: sal, dtype: float64

# %% [markdown]
# Self-Join: 직원과 매니저 정보를 하나의 데이터 프레임으로 merge(join)

# %%
pd.merge(emp, emp, left_on='mgr', right_on='empno')
# Out:
#     empno_x ename_x     job_x   mgr_x           hiredate_x   sal_x  comm_x  \
# 0      7369   SMITH     CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 1      7499   ALLEN  SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 2      7521    WARD  SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 3      7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 4      7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 5      7698   BLAKE   MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 6      7782   CLARK   MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 7      7788   SCOTT   ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 8      7844  TURNER  SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 9      7876   ADAMS     CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 10     7900   JAMES     CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 11     7902    FORD   ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 12     7934  MILLER     CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
#
#     deptno_x  empno_y ename_y      job_y   mgr_y           hiredate_y   sal_y  \
# 0         20     7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0
# 1         30     7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 2         30     7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 3         20     7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 4         30     7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 5         30     7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 6         10     7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 7         20     7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0
# 8         30     7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 9         20     7788   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0
# 10        30     7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 11        20     7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0
# 12        10     7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0
#
#     comm_y  deptno_y
# 0      NaN        20
# 1      NaN        30
# 2      NaN        30
# 3      NaN        10
# 4      NaN        30
# 5      NaN        10
# 6      NaN        10
# 7      NaN        20
# 8      NaN        30
# 9      NaN        20
# 10     NaN        30
# 11     NaN        20
# 12     NaN        10

# %%
pd.merge(emp, emp, how='left', left_on='mgr', right_on='empno')
# Out:
#     empno_x ename_x      job_x   mgr_x           hiredate_x   sal_x  comm_x  \
# 0      7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800.0     NaN
# 1      7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600.0   300.0
# 2      7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250.0   500.0
# 3      7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0     NaN
# 4      7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250.0  1400.0
# 5      7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0     NaN
# 6      7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0     NaN
# 7      7788   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0     NaN
# 8      7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0     NaN
# 9      7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500.0     0.0
# 10     7876   ADAMS      CLERK  7788.0  1987-05-23 00:00:00  1100.0     NaN
# 11     7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950.0     NaN
# 12     7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0     NaN
# 13     7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300.0     NaN
#
#     deptno_x  empno_y ename_y      job_y   mgr_y           hiredate_y   sal_y  \
# 0         20   7902.0    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000.0
# 1         30   7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 2         30   7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 3         20   7839.0    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 4         30   7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 5         30   7839.0    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 6         10   7839.0    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000.0
# 7         20   7566.0   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0
# 8         10      NaN     NaN        NaN     NaN                  NaN     NaN
# 9         30   7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 10        20   7788.0   SCOTT    ANALYST  7566.0  1987-04-19 00:00:00  3000.0
# 11        30   7698.0   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850.0
# 12        20   7566.0   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975.0
# 13        10   7782.0   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450.0
#
#     comm_y  deptno_y
# 0      NaN      20.0
# 1      NaN      30.0
# 2      NaN      30.0
# 3      NaN      10.0
# 4      NaN      30.0
# 5      NaN      10.0
# 6      NaN      10.0
# 7      NaN      20.0
# 8      NaN       NaN
# 9      NaN      30.0
# 10     NaN      20.0
# 11     NaN      30.0
# 12     NaN      20.0
# 13     NaN      10.0

# %% [markdown]
# # DataFrame 모양 바꾸기

# %% [markdown]
# ## `melt`

# %% [markdown]
# `pd.DataFrame.melt()` 메서드 : wide-form 데이터를 long-form 데이터로 변환
#
# * `id_vars` 파라미터 : melting 동작을 할 때 컬럼으로 유지할 컬럼 이름(들).
#     * `id_vars`로 설정하지 않은 모든 변수(컬럼)들은 `variable` 컬럼으로 melting됨.
#     * `id_vars`로 설정하지 않은 모든 변수(컬럼)들의 셀에 있는 값들은 `value`컬럼으로 melting됨.
# * `var_name` 파라미터: `variable` 컬럼의 이름으로 사용할 문자열.
# * `value_name` 파라미터: `value` 컬럼의 이름으로 사용할 문자열.

# %%
df = pd.DataFrame({
    'gender':['Female', 'Male'],
    'lunch':[10,5],
    'dinner':[20, 30]
})
df
# Out:
#    gender  lunch  dinner
# 0  Female     10      20
# 1    Male      5      30

# %%
df.melt(id_vars=['gender'])
# Out:
#    gender variable  value
# 0  Female    lunch     10
# 1    Male    lunch      5
# 2  Female   dinner     20
# 3    Male   dinner     30

# %%
df.melt(id_vars=['gender'], var_name = 'time', value_name = 'size')
# Out:
#    gender    time  size
# 0  Female   lunch    10
# 1    Male   lunch     5
# 2  Female  dinner    20
# 3    Male  dinner    30

# %% [markdown]
# ## `pivot`

# %% [markdown]
# `pd.DataFrame.pivot()`메서드: long-form(세로로 긴) 데이터 프레임을 wide-form(가로로 긴) 데이터프레임으로 변환.
#
# * `index` 파라미터: pivoting한 데이터프레임에서 row index로 사용할 컬럼(들)의 이름.
# * `columns` 파라미터: pivoting한 데이터프레임에서 컬럼 이름으로 사용할 컬럼(들)의 이름.
# * `values`파라미터: pivoting한 데이터프레임의 각 셀에 채울 값들이 있는 컬럼(들)의 이름.

# %%
df2 = pd.DataFrame({
    'time': ['Lunch'] * 3 + ['Dinner']  * 3,
    'day' : ['Fri', 'Sat', 'Sun'] * 2,
    'total_bill': np.arange(10, 70, 10),
    'tip': np.arange(1, 7)
})

df2
# Out:
#      time  day  total_bill  tip
# 0   Lunch  Fri          10    1
# 1   Lunch  Sat          20    2
# 2   Lunch  Sun          30    3
# 3  Dinner  Fri          40    4
# 4  Dinner  Sat          50    5
# 5  Dinner  Sun          60    6

# %%
df2.pivot(index='time', columns='day', values='tip')
# Out:
# day     Fri  Sat  Sun
# time
# Dinner    4    5    6
# Lunch     1    2    3

# %%
df2.pivot(index='time', columns='day', values=['total_bill', 'tip'])
# Out:
#        total_bill         tip
# day           Fri Sat Sun Fri Sat Sun
# time
# Dinner         40  50  60   4   5   6
# Lunch          10  20  30   1   2   3

# %%
df2.columns
# Out:
# Index(['time', 'day', 'total_bill', 'tip'], dtype='object')

# %%
df2.pivot(index='day', columns='time', values='tip')
# Out:
# time  Dinner  Lunch
# day
# Fri        4      1
# Sat        5      2
# Sun        6      3

# %%
df2.pivot(index='day', columns='time', values=['total_bill', 'tip'])
# Out:
#      total_bill          tip
# time     Dinner Lunch Dinner Lunch
# day
# Fri          40    10      4     1
# Sat          50    20      5     2
# Sun          60    30      6     3

# %% [markdown]
# # groupby vs pivot_table

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# ## group by

# %%
# 성별 팁의 평
tips.groupby(by='sex', observed = True).tip.mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
# 성별 흡연여부별 팁의 평균
tips.groupby(by=['sex', 'smoker'], observed = True).tip.mean()
# Out:
# sex     smoker
# Male    Yes       3.051167
#         No        3.113402
# Female  Yes       2.931515
#         No        2.773519
# Name: tip, dtype: float64

# %%
# 성별 흡연여부별 팁/영수증 평균
result = tips.groupby(by=['sex', 'smoker'], observed = True)[['tip', 'total_bill']].mean()
result
# Out:
#                     tip  total_bill
# sex    smoker
# Male   Yes     3.051167   22.284500
#        No      3.113402   19.791237
# Female Yes     2.931515   17.977879
#        No      2.773519   18.105185

# %% [markdown]
# ## pivot table

# %% [markdown]
# `pd.DataFrame.pivot_table()` 메서드 파라미터:
#
# * `values`: pivoting을 해서 각 셀에 값으로 설정할 변수(들).
# * `index`: pivoting을 할 때 row index로 설정할 변수(들).
# * `columns`: pivoting을 할 때 컬럼 이름으로 설정할 변수(들).
# * `aggfunc`: aggregation function(집계 함수). 통계 값을 계산하는 함수 이름 또는 함수 객체.

# %%
result = result.reset_index()
result
# Out:
#       sex smoker       tip  total_bill
# 0    Male    Yes  3.051167   22.284500
# 1    Male     No  3.113402   19.791237
# 2  Female    Yes  2.931515   17.977879
# 3  Female     No  2.773519   18.105185

# %%
result.pivot(index='sex', columns='smoker', values=['tip', 'total_bill'])
# Out:
#              tip           total_bill
# smoker       Yes        No        Yes         No
# sex
# Male    3.051167  3.113402  22.284500  19.791237
# Female  2.931515  2.773519  17.977879  18.105185

# %%
# 성별 팁의 평균
tips.pivot_table(values = 'tip', index = 'sex', aggfunc = 'mean', observed=True)
# Out:
#              tip
# sex
# Male    3.089618
# Female  2.833448

# %%
# 성별 흡연여부별 팁의 평균
tips.pivot_table(values = 'tip', index=['sex', 'smoker'], observed=True)
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
tips.pivot_table(values = 'tip', index='sex', columns='smoker', observed=True)
# Out:
# smoker       Yes        No
# sex
# Male    3.051167  3.113402
# Female  2.931515  2.773519

# %%
# 성별 흡연여부별 팁/영수증 평균
tips.pivot_table(values = ['tip', 'total_bill'], index='sex', columns='smoker', aggfunc = 'mean', observed=True)
# Out:
#              tip           total_bill
# smoker       Yes        No        Yes         No
# sex
# Male    3.051167  3.113402  22.284500  19.791237
# Female  2.931515  2.773519  17.977879  18.105185

# %% [markdown]
# 성별, 흡연여부별, 요일별, 시간별 팁/영수증의 평균을 계산하세요.
# 성별/흡연여부는 행 인덱스로 사용하고, 요일/시간은 컬럼 인덱스로 사용하세요.

# %%
tips.pivot_table(values = ['tip', 'total_bill'], index=['sex', 'smoker'], columns=['day', 'time'], aggfunc = 'mean', observed=True)
# Out:
#                     tip                                         total_bill  \
# day                Thur          Fri              Sat       Sun       Thur
# time              Lunch Dinner Lunch Dinner    Dinner    Dinner      Lunch
# sex    smoker
# Male   Yes     3.058000    NaN  1.90  3.246  2.879259  3.521333  19.171000
#        No      2.941500    NaN   NaN  2.500  3.256563  3.115349  18.486500
# Female Yes     2.990000    NaN  2.66  2.700  2.868667  3.500000  19.218571
#        No      2.437083    3.0  3.00  3.250  2.724615  3.329286  15.899167
#
#
# day                         Fri                Sat        Sun
# time          Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes       NaN  11.386667  25.892  21.837778  26.141333
#        No        NaN        NaN  17.475  19.929063  20.403256
# Female Yes       NaN  13.260000  12.200  20.266667  16.540000
#        No      18.78  15.980000  22.750  19.003846  20.824286

# %% [markdown]
# 집계 함수(aggfunc)가 여러 개인 경우

# %%
# 성별 요일별 팁의 평균, 최솟값, 최댓값

tips.pivot_table(values = 'tip', index=['sex', 'day'], aggfunc = ['mean', 'min', 'max'], observed=True)
# Out:
#                  mean   min    max
#                   tip   tip    tip
# sex    day
# Male   Thur  2.980333  1.44   6.70
#        Fri   2.693000  1.50   4.73
#        Sat   3.083898  1.00  10.00
#        Sun   3.220345  1.32   6.50
# Female Thur  2.575625  1.25   5.17
#        Fri   2.781111  1.00   4.30
#        Sat   2.801786  1.00   6.50
#        Sun   3.367222  1.01   5.20

# %%
tips.pivot_table(values='tip', index='sex', columns='day', aggfunc=['mean', 'min', 'max'], observed=True)
# Out:
#             mean                                 min                   max  \
# day         Thur       Fri       Sat       Sun  Thur  Fri  Sat   Sun  Thur
# sex
# Male    2.980333  2.693000  3.083898  3.220345  1.44  1.5  1.0  1.32  6.70
# Female  2.575625  2.781111  2.801786  3.367222  1.25  1.0  1.0  1.01  5.17
#
#
# day      Fri   Sat  Sun
# sex
# Male    4.73  10.0  6.5
# Female  4.30   6.5  5.2
